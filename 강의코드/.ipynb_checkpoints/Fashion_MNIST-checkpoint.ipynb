# %% [markdown]
# ## FashionMNIST 실습

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data 불러오기

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
print(train_images.shape)
print(train_labels.shape)
# Out:
# (60000, 28, 28)
# (60000,)

# %%
plt.imshow(train_images[5000])

# %% [markdown]
# ### 데이터 탐색

# %% [markdown]
# > Labels
# Each training and test example is assigned to one of the following labels:
#
# + 0 T-shirt/top
# + 1 Trouser
# + 2 Pullover
# + 3 Dress
# + 4 Coat
# + 5 Sandal
# + 6 Shirt
# + 7 Sneaker
# + 8 Bag
# + 9 Ankle boot

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
plt.figure(figsize=(20,20))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.grid(False)
    plt.imshow(train_images[i])
    plt.xlabel(train_labels[i])
plt.show()

# %%
BUFFER_SIZE=10000
suffled_train =

# %% [markdown]
# ### 모델 만들기

# %%
def set_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28, 28)),
        tf.keras.layers.Dense(5000, activation='relu'),
        tf.keras.layers.Dense(5000, activation='relu'),
        tf.keras.layers.Dense(5000, activation='relu'),
        tf.keras.layers.Dense(5000, activation='relu'),
        tf.keras.layers.Dense(5000, activation='relu'),
        tf.keras.layers.Dense(5000, activation='relu'),
        tf.keras.layers.Dense(5000, activation='relu'),
        tf.keras.layers.Dense(5000, activation='relu'),
        tf.keras.layers.Dense(5000, activation='relu'),
        tf.keras.layers.Dense(5000, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    
    model.compile(tf.keras.optimizers.Adam(lr=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
model = set_model()

model.fit(train_images, train_labels,
          epochs=20,
          validation_split=0.2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 31s 637us/sample - loss: 1.1389 - accuracy: 0.5664 - val_loss: 0.8929 - val_accuracy: 0.6455
# Epoch 2/20
# 48000/48000 [==============================] - 30s 621us/sample - loss: 0.6543 - accuracy: 0.7560 - val_loss: 0.5937 - val_accuracy: 0.7896
# Epoch 3/20
# 48000/48000 [==============================] - 30s 621us/sample - loss: 0.5696 - accuracy: 0.7980 - val_loss: 0.5299 - val_accuracy: 0.8122
# Epoch 4/20
# 48000/48000 [==============================] - 30s 621us/sample - loss: 0.5692 - accuracy: 0.8056 - val_loss: 0.4813 - val_accuracy: 0.8397
# Epoch 5/20
# 48000/48000 [==============================] - 30s 619us/sample - loss: 0.5168 - accuracy: 0.8281 - val_loss: 0.4618 - val_accuracy: 0.8421
# Epoch 6/20
# 48000/48000 [==============================] - 30s 617us/sample - loss: 0.4673 - accuracy: 0.8470 - val_loss: 0.4482 - val_accuracy: 0.8441
# Epoch 7/20
# 48000/48000 [==============================] - 30s 624us/sample - loss: 0.4208 - accuracy: 0.8572 - val_loss: 0.4124 - val_accuracy: 0.8522
# Epoch 8/20
# 48000/48000 [==============================] - 30s 620us/sample - loss: 0.3803 - accuracy: 0.8666 - val_loss: 0.3791 - val_accuracy: 0.8673
# Epoch 9/20
# 48000/48000 [==============================] - 30s 617us/sample - loss: 0.3626 - accuracy: 0.8736 - val_loss: 0.4067 - val_accuracy: 0.8592
# Epoch 10/20
# 48000/48000 [==============================] - 30s 623us/sample - loss: 0.3810 - accuracy: 0.8708 - val_loss: 0.3746 - val_accuracy: 0.8685
# Epoch 11/20
# 48000/48000 [==============================] - 30s 622us/sample - loss: 0.3358 - accuracy: 0.8811 - val_loss: 0.3693 - val_accuracy: 0.8708
# Epoch 12/20
# 48000/48000 [==============================] - 30s 620us/sample - loss: 0.3473 - accuracy: 0.8799 - val_loss: 0.4576 - val_accuracy: 0.8478
# Epoch 13/20
# 48000/48000 [==============================] - 30s 618us/sample - loss: 0.3218 - accuracy: 0.8871 - val_loss: 0.3723 - val_accuracy: 0.8679
# Epoch 14/20
# 48000/48000 [==============================] - 30s 622us/sample - loss: 0.3251 - accuracy: 0.8865 - val_loss: 0.3689 - val_accuracy: 0.8707
# Epoch 15/20
# 48000/48000 [==============================] - 30s 620us/sample - loss: 0.3089 - accuracy: 0.8918 - val_loss: 0.3909 - val_accuracy: 0.8626
# Epoch 16/20
# 48000/48000 [==============================] - 30s 629us/sample - loss: 0.3019 - accuracy: 0.8937 - val_loss: 0.3533 - val_accuracy: 0.8831
# Epoch 17/20
# 48000/48000 [==============================] - 30s 623us/sample - loss: 0.2928 - accuracy: 0.8961 - val_loss: 0.3527 - val_accuracy: 0.8727
# Epoch 18/20
# 48000/48000 [==============================] - 30s 621us/sample - loss: 0.3154 - accuracy: 0.8952 - val_loss: 0.3410 - val_accuracy: 0.8827
# Epoch 19/20
# 48000/48000 [==============================] - 30s 619us/sample - loss: 0.2782 - accuracy: 0.9013 - val_loss: 0.3604 - val_accuracy: 0.8771
# Epoch 20/20
# 48000/48000 [==============================] - 30s 619us/sample - loss: 0.2814 - accuracy: 0.9013 - val_loss: 0.3884 - val_accuracy: 0.8789

# %%
loss, acc = model.evaluate(test_images, test_labels, verbose=2)
print('Test Accuracy:', acc)
# Out:
# 10000/1 - 2s - loss: 0.2951 - accuracy: 0.8700
# Test Accuracy: 0.87

# %% [markdown]
# ## Inference 예측하기

# %%
prediction = model.predict_classes(test_images)
prediction[:10]
# Out:
# array([9, 2, 1, 1, 6, 1, 4, 6, 5, 7])
